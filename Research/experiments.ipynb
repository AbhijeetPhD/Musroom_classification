# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/admin/genaibatch/Musroom_classification/Data/mushrooms.csv")

# %%
len(df)
# Out:
# 8124

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# Obervation:-
# 1. All the features are categorical

# %%
from sklearn import preprocessing 
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
sorted(df['cap-surface'].unique())
# Out:
# ['f', 'g', 's', 'y']

# %%
df['cap-surface']=df['cap-surface'].map({'f':1,'g':2,'s':3,'y':4})

# %%
df
# Out:
#      class cap-shape  cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x            3         n       t    p               f
# 1        e         x            3         y       t    a               f
# 2        e         b            3         w       t    l               f
# 3        p         x            4         w       t    p               f
# 4        e         x            3         g       f    n               f
# ...    ...       ...          ...       ...     ...  ...             ...
# 8119     e         k            3         n       f    n               a
# 8120     e         x            3         n       f    n               a
# 8121     e         f            3         n       f    n               a
# 8122     p         k            4         n       f    y               f
# 8123     e         x            3         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
# Encode labels in column 'species'. 
df['cap-shape']= label_encoder.fit_transform(df['cap-shape'])

# %%
df.head()
# Out:
#   class  cap-shape  cap-surface cap-color bruises odor gill-attachment  \
# 0     p          5            3         n       t    p               f
# 1     e          5            3         y       t    a               f
# 2     e          0            3         w       t    l               f
# 3     p          5            4         w       t    p               f
# 4     e          5            3         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
df['cap-color'].unique()
# Out:
# array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object)

# %%
df['cap-color']= label_encoder.fit_transform(df['cap-color'])

# %%
df['bruises'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
df['bruises']=df['bruises'].map({'f':1,'t':2})

# %%
df['odor'].unique()
# Out:
# array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object)

# %%
df['odor']= label_encoder.fit_transform(df['odor'])

# %%
df['gill-attachment'].unique()
# Out:
# array(['f', 'a'], dtype=object)

# %%
df['gill-attachment']=df['gill-attachment'].map({'a':1,'f':2})

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
print(df['gill-spacing'].unique())
df['gill-spacing']=df['gill-spacing'].map({'c':1,'w':2})

print(df['gill-size'].unique())
df['gill-size']=df['gill-size'].map({'b':1,'n':2})

print(df['gill-color'].unique())
df['gill-color']=label_encoder.fit_transform(df['gill-color'])
# Out:
# ['c' 'w']
# ['n' 'b']
# ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']

# %%
print(df['stalk-color-above-ring'].unique())
df['stalk-color-above-ring']=label_encoder.fit_transform(df['stalk-color-above-ring'])

print(df['stalk-color-below-ring'].unique())
df['stalk-color-below-ring']=label_encoder.fit_transform(df['stalk-color-below-ring'])

print(df['stalk-root'].unique())
df['stalk-root']=label_encoder.fit_transform(df['stalk-root'])

print(df['stalk-shape'].unique())
df['stalk-shape']=label_encoder.fit_transform(df['stalk-shape']
                                              )
print(df['stalk-surface-above-ring'].unique())
df['stalk-surface-above-ring']=label_encoder.fit_transform(df['stalk-surface-above-ring'])

print(df['stalk-surface-below-ring'].unique())
df['stalk-surface-below-ring']=label_encoder.fit_transform(df['stalk-surface-below-ring'])
# Out:
# ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# ['e' 'c' 'b' 'r' '?']
# ['e' 't']
# ['s' 'f' 'k' 'y']
# ['s' 'f' 'y' 'k']

# %%
print(df['veil-type'].unique())
df=df.drop(['veil-type'],axis=1)
print(df['veil-color'].unique())
df['veil-color']=df['veil-color'].map({'n':1,'o':2,'y':3,'w':4})
# Out:
# ['p']
# ['w' 'n' 'o' 'y']

# %%
sorted(df['ring-type'].unique())
# Out:
# ['e', 'f', 'l', 'n', 'p']

# %%
print(df['ring-number'].unique())
df['ring-number']=df['ring-number'].map({'n':1,'o':2,'t':3})
print(df['ring-type'].unique())
df['ring-type']=df['ring-type'].map({'e':1,'f':2,'l':3,'n':4,'p':5})
# Out:
# ['o' 't' 'n']
# ['p' 'e' 'l' 'f' 'n']

# %%
print(df['spore-print-color'].unique())
df['spore-print-color']=label_encoder.fit_transform(df['spore-print-color'])
# Out:
# ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']

# %%
print(df['population'].unique())

df['population']=label_encoder.fit_transform(df['population'])
# Out:
# ['s' 'n' 'a' 'v' 'y' 'c']

# %%
print(df['class'].unique())

df['class']=df['class'].map({'e':0,'p':1})
# Out:
# ['p' 'e']

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            3          4        2     6                2
# 1      0          5            3          9        2     0                2
# 2      0          0            3          8        2     3                2
# 3      1          5            4          8        2     6                2
# 4      0          5            3          3        1     5                2
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             1          2           4  ...                         2
# 1             1          1           4  ...                         2
# 2             1          1           5  ...                         2
# 3             1          2           5  ...                         2
# 4             2          1           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %%
print(df['habitat'].unique())

df['habitat']=label_encoder.fit_transform(df['habitat'])
# Out:
# ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int64
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int64
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int64
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int64
#  7   gill-spacing              8124 non-null   int64
#  8   gill-size                 8124 non-null   int64
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     2.827671     4.504677     1.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     1.000000     0.000000     1.000000
# 25%       0.000000     2.000000     1.000000     3.000000     1.000000
# 50%       0.000000     3.000000     3.000000     4.000000     1.000000
# 75%       1.000000     5.000000     4.000000     8.000000     2.000000
# max       1.000000     5.000000     4.000000     9.000000     2.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         1.974151      1.161497     1.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# Exploratory Data Analysis
